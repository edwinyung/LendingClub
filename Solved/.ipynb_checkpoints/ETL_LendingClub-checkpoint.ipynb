# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %% [markdown]
# ### Extract: Import into Pandas

# %%
source_file = "../Resources/LoanStats3a.csv"
original_df = pd.read_csv(source_file,skiprows=1, header='infer',low_memory=False)
original_df.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           4975.0   36 months
# 1  NaN        NaN     2500.0       2500.0           2500.0   60 months
# 2  NaN        NaN     2400.0       2400.0           2400.0   36 months
# 3  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 4  NaN        NaN     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   10.65%       162.87     B        B2       ...
# 1   15.27%        59.83     C        C4       ...
# 2   15.96%        84.33     C        C5       ...
# 3   13.49%       339.31     C        C1       ...
# 4   12.69%        67.79     B        B5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %% [markdown]
# ### Transform: Clean up Data

# %%
original_df.reset_index()
# Out:
#        index                                               id  member_id  \
# 0          0                                              NaN        NaN
# 1          1                                              NaN        NaN
# 2          2                                              NaN        NaN
# 3          3                                              NaN        NaN
# 4          4                                              NaN        NaN
# 5          5                                              NaN        NaN
# 6          6                                              NaN        NaN
# 7          7                                              NaN        NaN
# 8          8                                              NaN        NaN
# 9          9                                              NaN        NaN
# 10        10                                              NaN        NaN
# 11        11                                              NaN        NaN
# ...

# %%
source_cols = ["loan_amnt", "funded_amnt", "int_rate","grade"]
source_transformed = original_df[source_cols].copy()

#source_transformed = source_transformed.rename(columns={"loan_amnt": "Loan Amount",
#                                                          "funded_amnt": "Funded Amount",
#                                                          "int_rate": "Interest Rate",
#                                                         "grade": "Grade"})
source_transformed.dropna(subset=['loan_amnt','funded_amnt'])
source_transformed.head()
# Out:
#    loan_amnt  funded_amnt int_rate grade
# 0     5000.0       5000.0   10.65%     B
# 1     2500.0       2500.0   15.27%     C
# 2     2400.0       2400.0   15.96%     C
# 3    10000.0      10000.0   13.49%     C
# 4     3000.0       3000.0   12.69%     B

# %%
plt.scatter(source_transformed["loan_amnt"],source_transformed["funded_amnt"])

# %% [markdown]
# ### Load: Data into Database

# %%
connection_string = "root:<insert password>@localhost/customer_db"
engine = create_engine(f'mysql://{connection_string}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-77-c8341ca90a69> in <module>()
#       1 connection_string = "root:<insert password>@localhost/customer_db"
# ----> 2 engine = create_engine(f'mysql://{connection_string}')
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     417     strategy = kwargs.pop('strategy', default_strategy)
#     418     strategy = strategies.strategies[strategy]
# --> 419     return strategy.create(*args, **kwargs)
#     420
#     421
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      78                 if k in kwargs:
#      79                     dbapi_args[k] = pop_kwarg(k)
# ---> 80             dbapi = dialect_cls.dbapi(**dbapi_args)
#      81
#      82         dialect_args['dbapi'] = dbapi
#
# ...

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-d72bc75a6b62> in <module>()
# ----> 1 engine.table_names()
#
# NameError: name 'engine' is not defined

# %%
source_transformed.to_sql(name='original', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-f2904baf2a3d> in <module>()
# ----> 1 source_transformed.to_sql(name='original', con=engine, if_exists='append', index=True)
#
# NameError: name 'engine' is not defined
